# %% [markdown]
# # Find AKI patients in eICU database

# %%
import pandas as pd

# %%
patient_file = r"E:\EICU\eicu-collaborative-research-database-2.0\patient.csv.gz"
patient_df = pd.read_csv(patient_file, compression="gzip")

diagnosis_file = r"E:\EICU\eicu-collaborative-research-database-2.0\diagnosis.csv.gz"
diagnosis_df = pd.read_csv(diagnosis_file, compression="gzip")

# %% [markdown]
# ### Step1: Find patients with AKI(88,288)

# %%
# ICD-9 584.x (AKI)
diagnosis_df['icd9code'] = diagnosis_df['icd9code'].astype(str).str.strip()
def contains_aki(icd9_list):
    icd9_codes = [code.strip() for code in icd9_list.split(',')]
    return any(code.startswith('584') for code in icd9_codes)

aki_diag = diagnosis_df[diagnosis_df['icd9code'].apply(contains_aki)]

# %%
aki_diag
# Out:
#          diagnosisid  patientunitstayid  activeupondischarge  diagnosisoffset  \
# 36           4269128             141266                 True               96
# 93           3539282             141304                 True              260
# 101          4017918             141314                 True              125
# 209          4130667             141448                 True               17
# 219          3743308             141470                 True               13
# ...              ...                ...                  ...              ...
# 2710639     46300378            3353251                False             2653
# 2710641     46290865            3353251                False            11304
# 2710649     46299599            3353251                False             1201
# 2710657     46289644            3353251                False             4080
# 2710669     46259796            3353254                 True               41
#
#                                            diagnosisstring      icd9code  \
# 36            renal|disorder of kidney|acute renal failure  584.9, N17.9
# 93            renal|disorder of kidney|acute renal failure  584.9, N17.9
# 101           renal|disorder of kidney|acute renal failure  584.9, N17.9
# 209           renal|disorder of kidney|acute renal failure  584.9, N17.9
# 219           renal|disorder of kidney|acute renal failure  584.9, N17.9
# ...                                                    ...           ...
# 2710639       renal|disorder of kidney|acute renal failure  584.9, N17.9
# 2710641       renal|disorder of kidney|acute renal failure  584.9, N17.9
# 2710649       renal|disorder of kidney|acute renal failure  584.9, N17.9
# 2710657       renal|disorder of kidney|acute renal failure  584.9, N17.9
# 2710669  renal|disorder of kidney|acute renal failure|d...  584.9, N17.9
#
#         diagnosispriority
# 36                  Other
# 93                  Other
# 101                 Other
# 209                 Other
# 219                 Major
# ...                   ...
# 2710639             Other
# 2710641             Major
# 2710649             Other
# 2710657             Major
# 2710669             Major
#
# [88288 rows x 7 columns]

# %%
aki_df = patient_df.merge(aki_diag[['patientunitstayid']], on='patientunitstayid', how='inner')

# %%
aki_df
# Out:
#        patientunitstayid  patienthealthsystemstayid  gender age  \
# 0                 141266                     129000    Male  73
# 1                 141304                     129031    Male  70
# 2                 141314                     129039    Male  45
# 3                 141448                     129154    Male  65
# 4                 141470                     129172  Female  58
# ...                  ...                        ...     ...  ..
# 88283            3353251                    2743099    Male  73
# 88284            3353251                    2743099    Male  73
# 88285            3353251                    2743099    Male  73
# 88286            3353251                    2743099    Male  73
# 88287            3353254                    2743102    Male  81
#
#               ethnicity  hospitalid  wardid  \
# 0             Caucasian          71     113
# 1             Caucasian          59      91
# 2             Caucasian          73      85
# 3              Hispanic          73     100
# 4             Caucasian          66      90
# ...                 ...         ...     ...
# 88283  African American         458    1104
# 88284  African American         458    1104
# 88285  African American         458    1104
# 88286  African American         458    1104
# 88287         Caucasian         459    1108
#
#                                        apacheadmissiondx  admissionheight  \
# 0                  Sepsis, renal/UTI (including bladder)            188.0
# 1                                      Sepsis, pulmonary            165.0
# 2               Aneurysm, abdominal aortic; with rupture            170.2
# 3      Coma/change in level of consciousness (for hep...            167.6
# 4      Obstruction/other, surgery for (with or withou...            162.6
# ...                                                  ...              ...
# 88283  Cardiac arrest (with or without respiratory ar...            177.8
# 88284  Cardiac arrest (with or without respiratory ar...            177.8
# 88285  Cardiac arrest (with or without respiratory ar...            177.8
# 88286  Cardiac arrest (with or without respiratory ar...            177.8
# 88287                                 Bleeding, lower GI            185.4
#
#       hospitaladmittime24  ...       unitadmitsource unitvisitnumber  \
# 0                21:25:00  ...  Emergency Department               1
# 1                08:54:00  ...  Emergency Department               1
# 2                00:41:00  ...        Operating Room               2
# 3                08:33:00  ...  Emergency Department               1
# 4                07:23:00  ...        Operating Room               1
# ...                   ...  ...                   ...             ...
# 88283            12:51:00  ...  Emergency Department               1
# 88284            12:51:00  ...  Emergency Department               1
# 88285            12:51:00  ...  Emergency Department               1
# 88286            12:51:00  ...  Emergency Department               1
# 88287            07:43:00  ...  Emergency Department               1
#
#        unitstaytype admissionweight  dischargeweight unitdischargetime24  \
# 0             admit           120.4            112.9            22:44:00
# 1             admit             NaN             68.0            23:36:00
# 2          transfer             NaN            102.6            18:39:00
# 3             admit            79.8             87.2            00:56:00
# 4             admit             NaN            108.6            21:19:00
# ...             ...             ...              ...                 ...
# 88283         admit           102.0             96.2            23:16:00
# 88284         admit           102.0             96.2            23:16:00
# 88285         admit           102.0             96.2            23:16:00
# 88286         admit           102.0             96.2            23:16:00
# 88287         admit            83.9             92.9            19:25:00
#
#       unitdischargeoffset unitdischargelocation unitdischargestatus  uniquepid
# 0                    1501                 Floor               Alive  002-76877
# 1                    6639                 Floor               Alive  002-75420
# 2                     632                 Death             Expired  002-70742
# 3                     983                 Floor               Alive   002-5376
# 4                     831                 Floor               Alive  002-56630
# ...                   ...                   ...                 ...        ...
# 88283               16259             Telemetry               Alive   035-5166
# 88284               16259             Telemetry               Alive   035-5166
# 88285               16259             Telemetry               Alive   035-5166
# 88286               16259             Telemetry               Alive   035-5166
# 88287                 431  Step-Down Unit (SDU)               Alive  035-19511
#
# [88288 rows x 29 columns]

# %% [markdown]
# ### Step2: Find patients with AKI(88,288) and ICU stay > 24 hours

# %%
aki_df = aki_df[aki_df['unitdischargeoffset'] > 24 * 60]
aki_df = aki_df.sort_values(by=['patienthealthsystemstayid', 'hospitaladmitoffset'])
aki_df = aki_df.drop_duplicates(subset=['patienthealthsystemstayid'], keep='first')

# %%
def clean_age(age):
    if age == ">89":
        return 90
    elif age.isdigit():  
        return int(age)
    else:
        return None

aki_df['age'] = aki_df['age'].astype(str).str.strip().apply(clean_age)

# 只保留 `age > 18` 的患者
aki_df = aki_df[aki_df['age'] > 18]

# %%
aki_df
# Out:
#        patientunitstayid  patienthealthsystemstayid  gender   age  \
# 0                 141266                     129000    Male  73.0
# 1                 141304                     129031    Male  70.0
# 5                 141515                     129205  Female  68.0
# 9                 141594                     129267    Male  76.0
# 11                141751                     129381  Female  60.0
# ...                  ...                        ...     ...   ...
# 88254            3353144                    2743005    Male  51.0
# 88260            3353190                    2743049    Male  39.0
# 88261            3353194                    2743053  Female  51.0
# 88273            3353199                    2743055  Female  66.0
# 88276            3353251                    2743099    Male  73.0
#
#               ethnicity  hospitalid  wardid  \
# 0             Caucasian          71     113
# 1             Caucasian          59      91
# 5             Caucasian          73     114
# 9             Caucasian          71     113
# 11            Caucasian          71      87
# ...                 ...         ...     ...
# 88254  African American         458    1106
# 88260         Caucasian         458    1106
# 88261     Other/Unknown         458    1109
# 88273         Caucasian         458    1104
# 88276  African American         458    1104
#
#                                        apacheadmissiondx  admissionheight  \
# 0                  Sepsis, renal/UTI (including bladder)            188.0
# 1                                      Sepsis, pulmonary            165.0
# 5                                        Sepsis, unknown            165.1
# 9                          CHF, congestive heart failure            182.9
# 11                                       Sepsis, unknown            165.1
# ...                                                  ...              ...
# 88254                               Renal failure, acute            180.3
# 88260  Coma/change in level of consciousness (for hep...            180.3
# 88261  Cardiac arrest (with or without respiratory ar...            170.2
# 88273                              Pneumonia, aspiration            157.5
# 88276  Cardiac arrest (with or without respiratory ar...            177.8
#
#       hospitaladmittime24  ...       unitadmitsource unitvisitnumber  \
# 0                21:25:00  ...  Emergency Department               1
# 1                08:54:00  ...  Emergency Department               1
# 5                19:43:00  ...                 Floor               1
# 9                17:56:00  ...                 Floor               1
# 11               05:34:00  ...  Emergency Department               1
# ...                   ...  ...                   ...             ...
# 88254            18:53:00  ...        Other Hospital               1
# 88260            19:35:00  ...  Step-Down Unit (SDU)               1
# 88261            07:17:00  ...  Emergency Department               1
# 88273            06:38:00  ...             Other ICU               2
# 88276            12:51:00  ...  Emergency Department               1
#
#        unitstaytype admissionweight  dischargeweight unitdischargetime24  \
# 0             admit          120.40            112.9            22:44:00
# 1             admit             NaN             68.0            23:36:00
# 5             admit           70.90             76.0            17:57:00
# 9             admit          108.30             97.9            01:08:00
# 11            admit             NaN             67.7            20:15:00
# ...             ...             ...              ...                 ...
# 88254         admit           39.20             42.2            20:10:00
# 88260         admit          110.60            101.0            00:32:00
# 88261         admit           63.05             65.8            21:57:00
# 88273      transfer           71.50             96.8            23:37:00
# 88276         admit          102.00             96.2            23:16:00
#
#       unitdischargeoffset unitdischargelocation unitdischargestatus  uniquepid
# 0                    1501                 Floor               Alive  002-76877
# 1                    6639                 Floor               Alive  002-75420
# 5                    8882                 Floor               Alive  002-48364
# 9                    6011                 Floor               Alive  002-25121
# 11                   5189                 Floor               Alive  002-75863
# ...                   ...                   ...                 ...        ...
# 88254               15917  Step-Down Unit (SDU)               Alive  035-20783
# 88260                3051                 Floor               Alive   035-7770
# 88261                3590                 Death             Expired   035-2735
# 88273               10547  Step-Down Unit (SDU)               Alive  035-18808
# 88276               16259             Telemetry               Alive   035-5166
#
# [14209 rows x 29 columns]

# %%
aki_df['patientunitstayid'].nunique()
# Out:
# 14209

# %%
missing_ratio = aki_df.isnull().mean(axis=1)
aki_df = aki_df[missing_ratio < 0.3]

# %%
aki_df
# Out:
#        patientunitstayid  patienthealthsystemstayid  gender   age  \
# 0                 141266                     129000    Male  73.0
# 1                 141304                     129031    Male  70.0
# 5                 141515                     129205  Female  68.0
# 9                 141594                     129267    Male  76.0
# 11                141751                     129381  Female  60.0
# ...                  ...                        ...     ...   ...
# 88254            3353144                    2743005    Male  51.0
# 88260            3353190                    2743049    Male  39.0
# 88261            3353194                    2743053  Female  51.0
# 88273            3353199                    2743055  Female  66.0
# 88276            3353251                    2743099    Male  73.0
#
#               ethnicity  hospitalid  wardid  \
# 0             Caucasian          71     113
# 1             Caucasian          59      91
# 5             Caucasian          73     114
# 9             Caucasian          71     113
# 11            Caucasian          71      87
# ...                 ...         ...     ...
# 88254  African American         458    1106
# 88260         Caucasian         458    1106
# 88261     Other/Unknown         458    1109
# 88273         Caucasian         458    1104
# 88276  African American         458    1104
#
#                                        apacheadmissiondx  admissionheight  \
# 0                  Sepsis, renal/UTI (including bladder)            188.0
# 1                                      Sepsis, pulmonary            165.0
# 5                                        Sepsis, unknown            165.1
# 9                          CHF, congestive heart failure            182.9
# 11                                       Sepsis, unknown            165.1
# ...                                                  ...              ...
# 88254                               Renal failure, acute            180.3
# 88260  Coma/change in level of consciousness (for hep...            180.3
# 88261  Cardiac arrest (with or without respiratory ar...            170.2
# 88273                              Pneumonia, aspiration            157.5
# 88276  Cardiac arrest (with or without respiratory ar...            177.8
#
#       hospitaladmittime24  ...       unitadmitsource unitvisitnumber  \
# 0                21:25:00  ...  Emergency Department               1
# 1                08:54:00  ...  Emergency Department               1
# 5                19:43:00  ...                 Floor               1
# 9                17:56:00  ...                 Floor               1
# 11               05:34:00  ...  Emergency Department               1
# ...                   ...  ...                   ...             ...
# 88254            18:53:00  ...        Other Hospital               1
# 88260            19:35:00  ...  Step-Down Unit (SDU)               1
# 88261            07:17:00  ...  Emergency Department               1
# 88273            06:38:00  ...             Other ICU               2
# 88276            12:51:00  ...  Emergency Department               1
#
#        unitstaytype admissionweight  dischargeweight unitdischargetime24  \
# 0             admit          120.40            112.9            22:44:00
# 1             admit             NaN             68.0            23:36:00
# 5             admit           70.90             76.0            17:57:00
# 9             admit          108.30             97.9            01:08:00
# 11            admit             NaN             67.7            20:15:00
# ...             ...             ...              ...                 ...
# 88254         admit           39.20             42.2            20:10:00
# 88260         admit          110.60            101.0            00:32:00
# 88261         admit           63.05             65.8            21:57:00
# 88273      transfer           71.50             96.8            23:37:00
# 88276         admit          102.00             96.2            23:16:00
#
#       unitdischargeoffset unitdischargelocation unitdischargestatus  uniquepid
# 0                    1501                 Floor               Alive  002-76877
# 1                    6639                 Floor               Alive  002-75420
# 5                    8882                 Floor               Alive  002-48364
# 9                    6011                 Floor               Alive  002-25121
# 11                   5189                 Floor               Alive  002-75863
# ...                   ...                   ...                 ...        ...
# 88254               15917  Step-Down Unit (SDU)               Alive  035-20783
# 88260                3051                 Floor               Alive   035-7770
# 88261                3590                 Death             Expired   035-2735
# 88273               10547  Step-Down Unit (SDU)               Alive  035-18808
# 88276               16259             Telemetry               Alive   035-5166
#
# [14209 rows x 29 columns]

# %%
aki_df['patientunitstayid'].nunique()
# Out:
# 14209

# %%
# admission

def classify_admission(source):
    if isinstance(source, str):
        emergency_keywords = ["Emergency", "ICU"]
        elective_keywords = ["Acute Care", "Chest Pain Center","Direct Admit", "Floor", "Observation", "Operating Room", "PACU", "Recovery", "Step-Down", "Other Hospital","Other"]

        if any(keyword in source for keyword in emergency_keywords):
            return "Emergency"
        elif any(keyword in source for keyword in elective_keywords):
            return "Elective"
        else:
            return "Unknown"
    
# 应用到 aki_df
aki_df["admission_type"] = patient_df["unitadmitsource"].apply(classify_admission)

# %%
aki_df.to_csv('aki_patients.csv', index=False)

# %%
aki_df
# Out:
#        patientunitstayid  patienthealthsystemstayid  gender   age  \
# 0                 141266                     129000    Male  73.0
# 1                 141304                     129031    Male  70.0
# 5                 141515                     129205  Female  68.0
# 9                 141594                     129267    Male  76.0
# 11                141751                     129381  Female  60.0
# ...                  ...                        ...     ...   ...
# 88254            3353144                    2743005    Male  51.0
# 88260            3353190                    2743049    Male  39.0
# 88261            3353194                    2743053  Female  51.0
# 88273            3353199                    2743055  Female  66.0
# 88276            3353251                    2743099    Male  73.0
#
#               ethnicity  hospitalid  wardid  \
# 0             Caucasian          71     113
# 1             Caucasian          59      91
# 5             Caucasian          73     114
# 9             Caucasian          71     113
# 11            Caucasian          71      87
# ...                 ...         ...     ...
# 88254  African American         458    1106
# 88260         Caucasian         458    1106
# 88261     Other/Unknown         458    1109
# 88273         Caucasian         458    1104
# 88276  African American         458    1104
#
#                                        apacheadmissiondx  admissionheight  \
# 0                  Sepsis, renal/UTI (including bladder)            188.0
# 1                                      Sepsis, pulmonary            165.0
# 5                                        Sepsis, unknown            165.1
# 9                          CHF, congestive heart failure            182.9
# 11                                       Sepsis, unknown            165.1
# ...                                                  ...              ...
# 88254                               Renal failure, acute            180.3
# 88260  Coma/change in level of consciousness (for hep...            180.3
# 88261  Cardiac arrest (with or without respiratory ar...            170.2
# 88273                              Pneumonia, aspiration            157.5
# 88276  Cardiac arrest (with or without respiratory ar...            177.8
#
#       hospitaladmittime24  ...  unitvisitnumber unitstaytype  admissionweight  \
# 0                21:25:00  ...                1        admit           120.40
# 1                08:54:00  ...                1        admit              NaN
# 5                19:43:00  ...                1        admit            70.90
# 9                17:56:00  ...                1        admit           108.30
# 11               05:34:00  ...                1        admit              NaN
# ...                   ...  ...              ...          ...              ...
# 88254            18:53:00  ...                1        admit            39.20
# 88260            19:35:00  ...                1        admit           110.60
# 88261            07:17:00  ...                1        admit            63.05
# 88273            06:38:00  ...                2     transfer            71.50
# 88276            12:51:00  ...                1        admit           102.00
#
#       dischargeweight  unitdischargetime24 unitdischargeoffset  \
# 0               112.9             22:44:00                1501
# 1                68.0             23:36:00                6639
# 5                76.0             17:57:00                8882
# 9                97.9             01:08:00                6011
# 11               67.7             20:15:00                5189
# ...               ...                  ...                 ...
# 88254            42.2             20:10:00               15917
# 88260           101.0             00:32:00                3051
# 88261            65.8             21:57:00                3590
# 88273            96.8             23:37:00               10547
# 88276            96.2             23:16:00               16259
#
#       unitdischargelocation unitdischargestatus  uniquepid admission_type
# 0                     Floor               Alive  002-76877       Elective
# 1                     Floor               Alive  002-75420      Emergency
# 5                     Floor               Alive  002-48364      Emergency
# 9                     Floor               Alive  002-25121      Emergency
# 11                    Floor               Alive  002-75863       Elective
# ...                     ...                 ...        ...            ...
# 88254  Step-Down Unit (SDU)               Alive  035-20783           None
# 88260                 Floor               Alive   035-7770      Emergency
# 88261                 Death             Expired   035-2735       Elective
# 88273  Step-Down Unit (SDU)               Alive  035-18808       Elective
# 88276             Telemetry               Alive   035-5166      Emergency
#
# [14209 rows x 30 columns]

# %%
aki_df['hospitaldischargestatus'].value_counts()
# Out:
# hospitaldischargestatus
# Alive      11450
# Expired     2622
# Name: count, dtype: int64

# %%
aki_df['hospitalid'].value_counts()
# Out:
# hospitalid
# 420    999
# 188    559
# 417    497
# 73     491
# 252    473
#       ...
# 263      1
# 437      1
# 414      1
# 179      1
# 86       1
# Name: count, Length: 196, dtype: int64

# %%
aki_420 = aki_df[aki_df['hospitalid'] == 420]

# %%
aki_420['hospitaldischargestatus'].value_counts()
# Out:
# hospitaldischargestatus
# Alive      777
# Expired    218
# Name: count, dtype: int64

# %%
aki_188 = aki_df[aki_df['hospitalid'] == 188]
aki_188['hospitaldischargestatus'].value_counts()
# Out:
# hospitaldischargestatus
# Alive      459
# Expired    100
# Name: count, dtype: int64
